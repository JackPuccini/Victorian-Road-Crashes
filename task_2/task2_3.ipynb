# %% [markdown]
# # Task 2.3 Analytical Questions

# %% [markdown]
# ### Part 1
#
# The TIME_OF_DAY pie charts and discuss any patterns or trends you observe and specifically, answer the question "What do the results tell you about the nature of accidents at different times of the day?"

# %%
from IPython.display import Image
Image(filename="task2_2_wordpies.png")

# %% [markdown]
# Referencing the pie charts for the Morning and Afternoon times, we see a higher proportion of the word 'intersections' (7 and 8% respectively) than for the Evening and Late Night categories (not featured). This suggests that accidents at intersections are more common during these times, possibly due to more traffic at intersections due to people travelling to and from places such as school and work at these times.
#
# Referencing the Late Night words pie chart, we can see a noticeably higher occurance of 'carriageway' (14%) compared to the Morning, Afternoon and Evening (9%, 8% and 10% respectively). This suggests that a higher proportion of accidents in the Late Night times occur on carriageways, possibly due to trucks, and other vehicles that predominantly use carriageways operate during these times. Also, the word 'bend' only features in the Late Night words category, potentially because accidents occuring near or due to bends being caused by driver fatigue, lack of focus or poor visibility rather than by congestion or traffic.

# %% [markdown]
# ### Part 2
#
# The variation between Mondays, Fridays and Sundays in accidents at different TIME_OF_DAY categories - specifically, answer the question "What do these results tell you about the nature of accidents occurring on these days?"

# %%
Image(filename="task2_2_stackbar.png")

# %% [markdown]
# Referencing the stacked bar chart, we see that most accidents occur during the Afternoon and Morning time periods, while the Evening and Late Night categories have fewer total accidents. This is likely due to reduced traffic volumes during the evening and night, compared to peak travel times in the morning and afternoon when people commute to and from work, school, and other activities. The Afternoon period has more accidents than the Morning, which may be partly attributed to greater driver fatigue later in the day.
#
# We can also see that Late Night accidents show the highest proportion on Sundays. This may reflect people staying out later on the weekend and commuting home during these hours. Additionally, higher rates of alcohol consumption on weekend nights could contribute to this elevated accident rate during Late Night on Sundays.
