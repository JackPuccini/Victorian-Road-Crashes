# %% [markdown]
# # Task 1.3 Analytical Questions

# %% [markdown]
# ### Part 1
#
# Age Group Analysis - specifically, answer the question "Which age group shows the most risky behaviour regarding seatbelt use?" Justify your answer using the bar chart results.

# %%
from IPython.display import Image
Image(filename="task1_2_age.png")

# %% [markdown]
# Referencing the bar chart, the 40–64 age group has the highest raw count of people not wearing seatbelts. However, when considering proportions, the Under 16 group has the lowest seatbelt usage rate at 82.1%, followed by the 65+ group at 87.6%.
#
# If we interpret 'risky behaviour' as the likelihood of not wearing a seatbelt, then the Under 16 age group exhibits the most risky behaviour.

# %% [markdown]
# ### Part 2
#
# Vehicle User Group Analysis - specifically, answer the question "Which vehicle user group (of drivers, front-seat passengers, or rear-seat passengers) exhibits the most risky behaviour?" Justify your answer using the pie charts.

# %%
Image(filename="task1_2_driver.png")

# %%
Image(filename="task1_2_seat.png")

# %% [markdown]
# From the pie chart comparing seatbelt use among drivers and passengers, we observe that passengers are less likely to wear seatbelts (97.3%) compared to drivers (98.5%).
#
# Furthermore, when comparing front-seat and back-seat passengers, we see that back-seat passengers have the lowest seatbelt usage rate at 95.7%, compared to 98.9% for front-seat passengers.
#
# Therefore, based on these charts, back-seat passengers exhibit the most risky behaviour in terms of seatbelt use.
